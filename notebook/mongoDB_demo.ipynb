# %%
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
df.head()
# Out:
# c:\Users\G.SAI\Desktop\Prediction System using End-to-End MLOps Pipeline (DVC, MLflow, Docker)\End-to-End-MLOps\mlopenv\Scripts\python.exe
